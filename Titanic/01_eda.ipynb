# %% [markdown]
# # **Titanic Survival Prediction — Exploratory Data Analysis**
#
# In this notebook we explore the Titanic dataset to understand its structure, distributions, relationships between features, and patterns that might help predict survival.

# %% [markdown]
# - Librería/Bibliotecas: conjunto de código preescrito, y funciones, de esta forma no se tienen que escribir de cero. Se usa la c¿palabra clave **import** y se les asigna una abreviatura para facilitar su uso.

# %%
# primero se imporan las librerías

import pandas as pd 
import numpy as np # Se utiliza para el análisis y manipulación de datos.
import matplotlib.pyplot as plt # Es la biblioteca principal para la visualización de datos estática.
import seaborn as sns # extensión de Matplotlib diseñada para hacer gráficos estadísticos más atractivos y sencillos. 

# Se establece un estilo
sns.set_theme(style="darkgrid") # Lo que va entre comillas se usa para adaptar la apariencia del gráfico, se puede camnbiar de acuerdo a las necesidades
plt.rcParams["figure.figsize"] = (12, 7) # Se modifica el tamño de la figura, 12pulgadas de ancho y 7 de alto
plt.rcParams["figure.dpi"] = 100 # Se comtrola la nitidez, 100 es lo estándar, pero puede mejorar a 300

# %matplotlib inline 
# Comando exclusivo de Jupyter, de esta forma los gráficos se mostrarán justo debajo de la celda de código
#(al parecer el comentario de arriba debía de ir en una líneaa aparte) si no, genera un error

# %% [markdown]
# 2. Cargar los datos

# %%
df = pd.read_csv("data/titanic.csv") # Lee el archivo csv, en la carpeta de data y lo convierte en un DataFrama: df
print(f"Dataset shape: {df.shape[0]} rows, {df.shape[1]} colums") # df.shape devuelve una tupla (filas, columnas)
# La f antes de las comillas permite insertar las variables directamente en el texto.
df.head(10) # muestra las primeras 10 filas
# Out:
# Dataset shape: 891 rows, 12 colums
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### Column Descriptions
#
# | Column | Description |
# | :--- | :--- |
# | **PassengerId** | Unique ID for each passenger |
# | **Survived** | 0 = Did not survive, 1 = Survived |
# | **Pclass** | Ticket class: 1 = 1st, 2 = 2nd, 3 = 3rd |
# | **Name** | Passenger name |
# | **Sex** | Gender |
# | **Age** | Age in years |
# | **SibSp** | Number of siblings/spouses aboard |
# | **Parch** | Number of parents/children aboard |
# | **Ticket** | Ticket number |
# | **Fare** | Passenger fare |
# | **Cabin** | Cabin number |
# | **Embarked** | Port of embarkation: C = Cherbourg, Q = Queenstown, S = Southampton |
